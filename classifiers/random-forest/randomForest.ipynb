# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../')
from datasets import data as Local ## Local module to get dataframes

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split

# %%
games_df, winners_df, cumulative_stats_df, games_details_df, teams_df, players_df, ranking_df = Local.get_all_dataset_dataframes('../../datasets/')

# %%
winners_df
# Out:
# 16157    1
# 16156    1
# 16155    1
# 16154    1
# 16153    1
#         ..
# 4        0
# 3        0
# 2        0
# 1        1
# 0        1
# Name: HOME_TEAM_WINS, Length: 23520, dtype: int64

# %%
games_df
# Out:
#       GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  \
# 16157    2003-10-05  10300001    1610612762       1610612742    2003
# 16156    2003-10-06  10300002    1610612763       1610612749    2003
# 16155    2003-10-07  10300009    1610612758       1610612746    2003
# 16154    2003-10-07  10300005    1610612757       1610612745    2003
# 16153    2003-10-07  10300007    1610612748       1610612755    2003
# ...             ...       ...           ...              ...     ...
# 4        2020-12-18  12000040    1610612761       1610612748    2020
# 3        2020-12-18  12000039    1610612754       1610612755    2020
# 2        2020-12-19  12000049    1610612763       1610612737    2020
# 1        2020-12-19  12000048    1610612764       1610612765    2020
# 0        2020-12-19  12000047    1610612753       1610612766    2020
#
#        PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  REB_home  \
# ...

# %%
cumulative_stats_df
# Out:
#              DATE   GAME_ID  SEASON_TYPE  SEASON  GAMES_PLAYED_home  \
# 0      2003-10-05  10300001            1    2003                  1
# 1      2003-10-06  10300002            1    2003                  1
# 2      2003-10-07  10300009            1    2003                  1
# 3      2003-10-07  10300005            1    2003                  1
# 4      2003-10-07  10300007            1    2003                  1
# ...           ...       ...          ...     ...                ...
# 23515  2020-12-18  12000040            1    2020                  3
# 23516  2020-12-18  12000039            1    2020                  3
# 23517  2020-12-19  12000049            1    2020                  4
# 23518  2020-12-19  12000048            1    2020                  3
# 23519  2020-12-19  12000047            1    2020                  4
#
#        GAMES_PLAYED_away  APG_total_home  FG_PCT_total_home  \
# 0                      1       23.000000           0.457000
# ...

# %%
cumulative_stats_copy_df = cumulative_stats_df.copy()
for key in ['DATE','GAME_ID','TEAM_ID_home','TEAM_ID_away','SEASON_TYPE','SEASON','GAMES_PLAYED_home','GAMES_PLAYED_away']:
    del cumulative_stats_copy_df[key]
# Only look at home teams
# cumulative_stats_copy_df = cumulative_stats_copy_df.loc[cumulative_stats_copy_df['AT_HOME']==True]
# del cumulative_stats_copy_df['AT_HOME']
cumulative_stats_copy_df
# Out:
#        APG_total_home  FG_PCT_total_home  FG3_PCT_total_home  \
# 0           23.000000           0.457000            0.143000
# 1           25.000000           0.494000            0.267000
# 2           19.000000           0.467000            0.444000
# 3           22.000000           0.527000            0.429000
# 4           15.000000           0.352000            0.222000
# ...               ...                ...                 ...
# 23515       25.666667           0.422333            0.354000
# 23516       23.666667           0.415667            0.342667
# 23517       28.250000           0.450000            0.346000
# 23518       22.666667           0.419000            0.312667
# 23519       24.500000           0.441500            0.335250
#
#        FT_PCT_total_home  PPG_total_home  RPG_total_home  APG_total_away  \
# 0               0.735000       90.000000       41.000000            20.0
# 1               0.618000      105.000000       48.000000            20.0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    cumulative_stats_copy_df,
    winners_df,
    train_size=0.8,
    random_state=0,
)

# %%
randomForest = RandomForestClassifier()

# %%
randomForest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print('Random Forest accuracy (no optimizations): %.2f' % randomForest.score(X_test, y_test))
# Out:
# Random Forest accuracy (no optimizations): 0.71

# %%
from sklearn.tree import plot_tree
from yellowbrick.model_selection import FeatureImportances

# %%
def plot_feature_importances(clf):
    viz = FeatureImportances(
        clf,
        labels=cumulative_stats_copy_df.columns,
    )
    viz.fit(
        cumulative_stats_copy_df,
        winners_df,
    )
    viz.show()

# %%
plot_feature_importances(randomForest)

# %%
def do_cv(classifier, cv_fun, params, x, y, **kwargs):
    clf = cv_fun(
        classifier,
        params,
        scoring='accuracy', # Optimize for the 'accuracy' score of the model.
        **kwargs,
    )
    clf.fit(x, y)
    return clf

# %%
randomForest.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
cv_maxdepth_clf = do_cv(
    RandomForestClassifier(random_state=0),
    GridSearchCV,
    {
        'max_depth': [*range(4,100)],
        'criterion': ['gini', 'entropy'],
    },
    X_train,
    y_train
#     random_state=0,
)
print('Best random forest accuracy (%s): %.2f' % (str(cv_maxdepth_clf.best_params_), cv_maxdepth_clf.score(X_test, y_test)))
#Best decision tree accuracy ({'criterion': 'entropy', 'max_depth': 13}): 0.72
# Out:
# Best random forest accuracy ({'criterion': 'entropy', 'max_depth': 13}): 0.72

# %%
plot_feature_importances(cv_maxdepth_clf.best_estimator_)

# %%
cv_impurity_clf = do_cv(
    RandomForestClassifier(random_state=0),
    GridSearchCV,
    {
        'min_impurity_decrease': [0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95],
        'criterion': ['gini', 'entropy'],
    },
    X_train,
    y_train,
#     random_state=0,
)
print('Best random forest accuracy (%s): %.2f' % (str(cv_impurity_clf.best_params_), cv_impurity_clf.score(X_test, y_test)))
# Out:
# Best random forest accuracy ({'criterion': 'gini', 'min_impurity_decrease': 0.0}): 0.71

# %%
plot_feature_importances(cv_impurity_clf.best_estimator_)

# %%
cv_max_leaves_clf = do_cv(
    RandomForestClassifier(random_state=0),
    GridSearchCV,
    {
        'max_leaf_nodes': [*range(2,100)],
        'criterion': ['gini', 'entropy'],
    },
    X_train,
    y_train,
#     random_state=0,
)
print('Best random forest accuracy (%s): %.2f' % (str(cv_max_leaves_clf.best_params_), cv_max_leaves_clf.score(X_test, y_test)))
#Best random forest accuracy ({'criterion': 'entropy', 'max_leaf_nodes': 80}): 0.72
# Out:
# Best random forest accuracy ({'criterion': 'entropy', 'max_leaf_nodes': 80}): 0.72

# %%
plot_feature_importances(cv_max_leaves_clf.best_estimator_)

# %%
cv_max_features_clf = do_cv(
    RandomForestClassifier(random_state=0),
    GridSearchCV,
    {
        'max_features': [*range(1,len(cumulative_stats_df.columns)//2+1), 'sqrt', 'log2', None],
        'criterion': ['gini', 'entropy'],
    },
    X_train,
    y_train,
#     random_state=0,
)
print('Best decision tree accuracy (%s): %.2f' % (str(cv_max_features_clf.best_params_), cv_max_features_clf.score(X_test, y_test)))
#Best decision tree accuracy ({'criterion': 'gini', 'max_features': 3}): 0.71
# Out:
# Best decision tree accuracy ({'criterion': 'gini', 'max_features': 3}): 0.71

# %%
plot_feature_importances(cv_max_features_clf.best_estimator_)

# %%
cv_all_features_clf = do_cv(
    RandomForestClassifier(random_state=0),
    GridSearchCV,
    {        
        'max_depth': [*range(4,100)],
        'max_leaf_nodes': [*range(2,100)],
        'min_impurity_decrease': [0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95],
        'max_features': [*range(1,len(cumulative_stats_df.columns)//2+1), 'sqrt', 'log2', None],
        'criterion': ['gini', 'entropy'],
    },
    X_train,
    y_train,
#     random_state=0,
)
print('Best random forest accuracy (%s): %.2f' % (str(cv_all_features_clf.best_params_), cv_all_features_clf.score(X_test, y_test)))

# %% [markdown]
# # Conclusion
#
# XGBoost with pruned parameter values found with `RandomizedSearchCV`.
#
# Almost same accuracy as guessing each target.
#
# ## HOME_TEAM_WINS
#
# Target to beat - 59.1% home winrate
#
# Achieved - **74% accuracy**
#
# |Pruning|Accuracy|0 Precision|0 Recall|0 f1-score|1 Precision|1 Recall|1 f1-score|
# |-|-|-|-|-|-|-|-|
# |None|0.71|0.73|0.85|0.78|0.66|0.46|0.54|
# |max_depth=183|0.74|0.75|0.88|0.81|0.71|0.52|0.60|
# |reg_lambda=0.7|0.70|0.73|0.84|0.78|0.65|0.47|0.55|
# |gamma=43|0.63|0.63|1.00|0.77|0.00|0.00|0.00|
# |scale_pos_weight=17|0.62|0.83|0.50|0.62|0.50|0.82|0.62|
#
# ## HOME_HIGHER_FG_PCT
#
# Target to beat - 55.0% rate of home having higher FGP
#
# Achieved - **72% accuracy**
#
# |Pruning|Accuracy|0 Precision|0 Recall|0 f1-score|1 Precision|1 Recall|1 f1-score|
# |-|-|-|-|-|-|-|-|
# |None|0.70|0.73|0.83|0.77|0.65|0.51|0.5|
# |max_depth=249|0.72|0.74|0.86|0.79|0.69|0.52|0.59|
# |reg_lambda=0.05|0.68|0.71|0.80|0.76|0.61|0.48|0.54|
# |gamma=367|0.61|0.61|1.00|0.76|0.00|0.00|0.00|
# |scale_pos_weight=66|0.53|0.77|0.34|0.47|0.44|0.84|0.58|
#
# ## HOME_HIGHER_FG3_PCT
#
# Target to beat - 50.8% rate of home having higher FG3
#
# Achieved - **67% accuracy**
#
# |Pruning|Accuracy|0 Precision|0 Recall|0 f1-score|1 Precision|1 Recall|1 f1-score|
# |-|-|-|-|-|-|-|-|
# |None|0.64|0.67|0.69|0.68|0.60|0.58|0.59|
# |max_depth=23|0.67|0.70|0.71|0.70|0.64|0.62|0.63|
# |reg_lambda=0.6|0.65|0.68|0.71|0.69|0.62|0.59|0.60|
# |gamma=68|0.55|0.55|1.00|0.71|0.00|0.00|0.00|
# |scale_pos_weight=253|0.56|0.78|0.29|0.42|0.51|0.90|0.65|
#
# ## HOME_HIGHER_FT_PCT
#
# Target to beat - 49.5% rate of home having higher FTP
#
# Achieved - **68% accuracy**
#
# |Pruning|Accuracy|0 Precision|0 Recall|0 f1-score|1 Precision|1 Recall|1 f1-score|
# |-|-|-|-|-|-|-|-|
# |None|0.65|0.69|0.60|0.64|0.62|0.71|0.67|
# |max_depth=492|0.65|0.68|0.59|0.64|0.62|0.70|0.66|
# |reg_lambda=0.65|0.68|0.68|0.62|0.65|0.62|0.68|0.65|
# |gamma=138|0.48|0.00|0.00|0.00|0.48|1.00|0.65|
# |scale_pos_weight=1|0.65|0.69|0.60|0.64|0.62|0.71|0.67|
#
# ## HOME_HIGHER_AST
#
# Target to beat - 55.0% rate of home having higher AST
#
# Achieved - **71% accuracy**
#
# |Pruning|Accuracy|0 Precision|0 Recall|0 f1-score|1 Precision|1 Recall|1 f1-score|
# |-|-|-|-|-|-|-|-|
# |None|0.68|0.71|0.79|0.75|0.62|0.52|0.56|
# |max_depth=29|0.71|0.73|0.81|0.77|0.66|0.54|0.60|
# |reg_lambda=0.95|0.67|0.71|0.78|0.74|0.61|0.52|0.56|
# |gamma=18|0.60|0.61|0.96|0.74|0.53|0.07|0.13|
# |scale_pos_weight=94|0.50|0.71|0.30|0.42|0.43|0.81|0.57|
#
# ## HOME_HIGHER_REB
#
# Target to beat - 53.4% rate of home having higher REB
#
# Achieved - **65% accuracy**
#
# |Pruning|Accuracy|0 Precision|0 Recall|0 f1-score|1 Precision|1 Recall|1 f1-score|
# |-|-|-|-|-|-|-|-|
# |None|0.63|0.67|0.73|0.70|0.57|0.50|0.53|
# |max_depth=377|0.60|0.69|0.77|0.73|0.61|0.51|0.56|
# |reg_lambda=0.7|0.65|0.68|0.74|0.71|0.59|0.51|0.55|
# |gamma=190|0.58|0.58|1.00|0.74|0.00|0.00|0.51|
# |scale_pos_weight=20|0.56|0.73|0.38|0.50|0.48|0.81|0.60|

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import sys
sys.path.append('../../')
from datasets import data as Local ## Local module to get dataframes

from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %%
games_df, winners_df, greater_fgp_df, greater_fg3_df, greater_ft_df, greater_ast_df, greater_reb_df, cumulative_stats_df, games_details_df, teams_df, players_df, ranking_df = \
    Local.get_all_dataset_dataframes('../../datasets/')

# %% [markdown]
# # Target datasets

# %% [markdown]
# - Home has:
#     - 59.1% Winrate
#     - 55.0% Rate of Higher FGP
#     - 50.8% Rate of Higher FG3
#     - 49.5% Rate of Higher FTP
#     - 55.0% Rate of Higher AST
#     - 53.4% Rate of Higher REB

# %%
winners_df # Whether the home team won in a game in each row of `games_df`
# Out:
# 16157    1
# 16156    1
# 16155    1
# 16154    1
# 16153    1
#         ..
# 4        0
# 3        0
# 2        0
# 1        1
# 0        1
# Name: HOME_TEAM_WINS, Length: 23520, dtype: int64

# %%
winners_df.describe()
# Out:
# count    23520.000000
# mean         0.591029
# std          0.491654
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: HOME_TEAM_WINS, dtype: float64

# %%
greater_fgp_df.describe()
# Out:
# count    23520.000000
# mean         0.550468
# std          0.497457
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: HOME_HIGHER_FG_PCT, dtype: float64

# %%
greater_fg3_df.describe()
# Out:
# count    23520.000000
# mean         0.507993
# std          0.499947
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: HOME_HIGHER_FG3_PCT, dtype: float64

# %%
greater_ft_df.describe()
# Out:
# count    23520.000000
# mean         0.494855
# std          0.499984
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: HOME_HIGHER_FT_PCT, dtype: float64

# %%
greater_ast_df.describe()
# Out:
# count    23520.000000
# mean         0.550128
# std          0.497491
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: HOME_HIGHER_AST, dtype: float64

# %%
greater_reb_df.describe()
# Out:
# count    23520.000000
# mean         0.533886
# std          0.498861
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: HOME_HIGHER_REB, dtype: float64

# %% [markdown]
# # Datasets

# %%
games_df
# Out:
#       GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  \
# 16157    2003-10-05  10300001    1610612762       1610612742    2003
# 16156    2003-10-06  10300002    1610612763       1610612749    2003
# 16155    2003-10-07  10300009    1610612758       1610612746    2003
# 16154    2003-10-07  10300005    1610612757       1610612745    2003
# 16153    2003-10-07  10300007    1610612748       1610612755    2003
# ...             ...       ...           ...              ...     ...
# 4        2020-12-18  12000040    1610612761       1610612748    2020
# 3        2020-12-18  12000039    1610612754       1610612755    2020
# 2        2020-12-19  12000049    1610612763       1610612737    2020
# 1        2020-12-19  12000048    1610612764       1610612765    2020
# 0        2020-12-19  12000047    1610612753       1610612766    2020
#
#        PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  REB_home  \
# 16157      90.0        0.457        0.735         0.143      23.0      41.0
# 16156     105.0        0.494        0.618         0.267      25.0      48.0
# 16155     101.0        0.467        0.871         0.444      19.0      39.0
# 16154     104.0        0.527        0.657         0.429      22.0      33.0
# 16153      86.0        0.352        0.647         0.222      15.0      55.0
# ...         ...          ...          ...           ...       ...       ...
# 4         105.0        0.380        0.737         0.356      27.0      37.0
# 3         107.0        0.371        0.692         0.262      19.0      45.0
# 2         116.0        0.400        0.744         0.396      21.0      43.0
# 1          99.0        0.427        0.625         0.295      24.0      45.0
# 0         120.0        0.433        0.792         0.425      23.0      50.0
#
#        PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away
# 16157      85.0        0.447        0.500         0.250      20.0      38.0
# 16156      94.0        0.427        0.700         0.154      20.0      43.0
# 16155      82.0        0.368        0.609         0.364      13.0      50.0
# 16154      80.0        0.470        0.667         0.333      10.0      37.0
# 16153      79.0        0.329        0.897         0.143       7.0      44.0
# ...         ...          ...          ...           ...       ...       ...
# 4         117.0        0.534        0.741         0.514      30.0      51.0
# 3         113.0        0.533        0.629         0.355      23.0      48.0
# 2         117.0        0.422        0.837         0.297      24.0      47.0
# 1          96.0        0.402        0.647         0.326      18.0      51.0
# 0         117.0        0.444        0.864         0.439      21.0      52.0
#
# [23520 rows x 17 columns]

# %%
cumulative_stats_df
# Out:
#              DATE   GAME_ID  SEASON_TYPE  SEASON  GAMES_PLAYED_home  \
# 0      2003-10-05  10300001            1    2003                  0
# 1      2003-10-06  10300002            1    2003                  0
# 2      2003-10-07  10300009            1    2003                  0
# 3      2003-10-07  10300005            1    2003                  0
# 4      2003-10-07  10300007            1    2003                  0
# ...           ...       ...          ...     ...                ...
# 23515  2020-12-18  12000040            1    2020                  2
# 23516  2020-12-18  12000039            1    2020                  2
# 23517  2020-12-19  12000049            1    2020                  3
# 23518  2020-12-19  12000048            1    2020                  2
# 23519  2020-12-19  12000047            1    2020                  3
#
#        GAMES_PLAYED_away  PPG_total_home  FG_PCT_total_home  \
# 0                      0        0.000000           0.000000
# 1                      0        0.000000           0.000000
# 2                      0        0.000000           0.000000
# 3                      0        0.000000           0.000000
# 4                      0        0.000000           0.000000
# ...                  ...             ...                ...
# 23515                  1      111.500000           0.443500
# 23516                  1      105.000000           0.438000
# 23517                  3      119.333333           0.466667
# 23518                  3      100.000000           0.415000
# 23519                  3      112.666667           0.444333
#
#        FG3_PCT_total_home  FT_PCT_total_home  ...  PPG_total_away  \
# 0                0.000000           0.000000  ...        0.000000
# 1                0.000000           0.000000  ...        0.000000
# 2                0.000000           0.000000  ...        0.000000
# 3                0.000000           0.000000  ...        0.000000
# 4                0.000000           0.000000  ...        0.000000
# ...                   ...                ...  ...             ...
# 23515            0.353000           0.691000  ...       92.000000
# 23516            0.383000           0.619000  ...      108.000000
# 23517            0.329333           0.704667  ...      111.333333
# 23518            0.321500           0.704500  ...       93.333333
# 23519            0.305333           0.758000  ...      110.666667
#
#        FG_PCT_total_away  FG3_PCT_total_away  FT_PCT_total_away  \
# 0               0.000000            0.000000           0.000000
# 1               0.000000            0.000000           0.000000
# 2               0.000000            0.000000           0.000000
# 3               0.000000            0.000000           0.000000
# 4               0.000000            0.000000           0.000000
# ...                  ...                 ...                ...
# 23515           0.427000            0.283000           0.818000
# 23516           0.471000            0.241000           0.750000
# 23517           0.392667            0.332333           0.789667
# 23518           0.413333            0.333000           0.713000
# 23519           0.442333            0.372333           0.751000
#
#        APG_total_away  RPG_total_away  TEAM_ID_away  TEAM_ID_home  W_PCT_away  \
# 0            0.000000        0.000000  1.610613e+09  1.610613e+09    0.000000
# 1            0.000000        0.000000  1.610613e+09  1.610613e+09    0.000000
# 2            0.000000        0.000000  1.610613e+09  1.610613e+09    0.000000
# 3            0.000000        0.000000  1.610613e+09  1.610613e+09    0.000000
# 4            0.000000        0.000000  1.610613e+09  1.610613e+09    0.000000
# ...               ...             ...           ...           ...         ...
# 23515       26.000000       35.000000  1.610613e+09  1.610613e+09    0.000000
# 23516       23.000000       42.000000  1.610613e+09  1.610613e+09    1.000000
# 23517       24.000000       56.000000  1.610613e+09  1.610613e+09    0.333333
# 23518       20.000000       41.666667  1.610613e+09  1.610613e+09    0.666667
# 23519       29.666667       45.000000  1.610613e+09  1.610613e+09    0.333333
#
#        W_PCT_home
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# ...           ...
# 23515    1.000000
# 23516    0.000000
# 23517    1.000000
# 23518    0.000000
# 23519    0.333333
#
# [23520 rows x 22 columns]

# %% [markdown]
# ## Attach target columns to dataset

# %%
cumulative_stats_copy_df = cumulative_stats_df.copy()
cumulative_stats_copy_df['home_win'] = winners_df
cumulative_stats_copy_df['greater_fgp'] = greater_fgp_df
cumulative_stats_copy_df['greater_fg3'] = greater_fg3_df
cumulative_stats_copy_df['greater_ft'] = greater_ft_df
cumulative_stats_copy_df['greater_ast'] = greater_ast_df
cumulative_stats_copy_df['greater_reb'] = greater_reb_df

# %% [markdown]
# ## Remove rows w/o data

# %%
cumulative_stats_copy_df = cumulative_stats_copy_df[(cumulative_stats_copy_df['GAMES_PLAYED_home']>0) & (cumulative_stats_copy_df['GAMES_PLAYED_away']>0)]

# Get new target datasets after row removal
winners_df = cumulative_stats_copy_df['home_win']
greater_fgp_df = cumulative_stats_copy_df['greater_fgp']
greater_fg3_df = cumulative_stats_copy_df['greater_fg3']
greater_ft_df = cumulative_stats_copy_df['greater_ft']
greater_ast_df = cumulative_stats_copy_df['greater_ast']
greater_reb_df = cumulative_stats_copy_df['greater_reb']

# %% [markdown]
# ## Remove non-data

# %%
# Delete non-data
for key in [
    'DATE','GAME_ID','TEAM_ID_home','TEAM_ID_away','SEASON_TYPE','SEASON','GAMES_PLAYED_home','GAMES_PLAYED_away',
    'home_win','greater_fgp','greater_fg3','greater_ft','greater_ast','greater_reb'
]:
    del cumulative_stats_copy_df[key]
# Only look at home teams
# cumulative_stats_copy_df = cumulative_stats_copy_df.loc[cumulative_stats_copy_df['AT_HOME']==True]
# del cumulative_stats_copy_df['AT_HOME']
cumulative_stats_copy_df
# Out:
#        PPG_total_home  FG_PCT_total_home  FG3_PCT_total_home  \
# 19         104.000000           0.527000            0.429000
# 21          86.000000           0.380000            0.188000
# 22          86.000000           0.352000            0.222000
# 23          58.000000           0.457000            0.667000
# 24          87.500000           0.432000            0.420000
# ...               ...                ...                 ...
# 23515      111.500000           0.443500            0.353000
# 23516      105.000000           0.438000            0.383000
# 23517      119.333333           0.466667            0.329333
# 23518      100.000000           0.415000            0.321500
# 23519      112.666667           0.444333            0.305333
#
#        FT_PCT_total_home  APG_total_home  RPG_total_home  PPG_total_away  \
# 19              0.657000       22.000000       33.000000      101.000000
# 21              0.852000       19.000000       37.000000      101.000000
# 22              0.647000       15.000000       55.000000       80.000000
# 23              0.700000       10.000000       31.000000       89.000000
# 24              0.672000       20.500000       43.000000       79.000000
# ...                  ...             ...             ...             ...
# 23515           0.691000       25.000000       41.500000       92.000000
# 23516           0.619000       26.000000       35.500000      108.000000
# 23517           0.704667       30.666667       52.666667      111.333333
# 23518           0.704500       22.000000       44.500000       93.333333
# 23519           0.758000       25.000000       51.333333      110.666667
#
#        FG_PCT_total_away  FG3_PCT_total_away  FT_PCT_total_away  \
# 19              0.467000            0.444000           0.871000
# 21              0.464000            0.250000           0.679000
# 22              0.350000            0.429000           0.750000
# 23              0.462000            0.214000           0.538000
# 24              0.329000            0.143000           0.897000
# ...                  ...                 ...                ...
# 23515           0.427000            0.283000           0.818000
# 23516           0.471000            0.241000           0.750000
# 23517           0.392667            0.332333           0.789667
# 23518           0.413333            0.333000           0.713000
# 23519           0.442333            0.372333           0.751000
#
#        APG_total_away  RPG_total_away  W_PCT_away  W_PCT_home
# 19          19.000000       39.000000    1.000000    1.000000
# 21          22.000000       47.000000    1.000000    0.000000
# 22          18.000000       45.000000    0.000000    1.000000
# 23          21.000000       36.000000    0.000000    0.000000
# 24           7.000000       44.000000    0.000000    0.500000
# ...               ...             ...         ...         ...
# 23515       26.000000       35.000000    0.000000    1.000000
# 23516       23.000000       42.000000    1.000000    0.000000
# 23517       24.000000       56.000000    0.333333    1.000000
# 23518       20.000000       41.666667    0.666667    0.000000
# 23519       29.666667       45.000000    0.333333    0.333333
#
# [23147 rows x 14 columns]

# %% [markdown]
# ## Train test split

# %%
from imblearn.combine import SMOTEENN

# %%
X_train_dict = {}
X_test_dict = {}
y_train_dict = {}
y_test_dict = {}

for target, key in [(winners_df, 'winner'), (greater_fgp_df, 'fgp'), (greater_fg3_df, 'fg3'), (greater_ft_df, 'ft'), (greater_ast_df, 'ast'), (greater_reb_df, 'reb')]:
    X_over, y_over = SMOTEENN(sampling_strategy='all').fit_resample(cumulative_stats_copy_df, target)
    X_train_dict[key], X_test_dict[key], y_train_dict[key], y_test_dict[key] = train_test_split(
        X_over,
        y_over,
        train_size=0.8,
        random_state=0,
    )

# %% [markdown]
# ## Do hyperparameters searches

# %%
from sklearn.tree import plot_tree
from yellowbrick.model_selection import FeatureImportances

# %%
XGBClassifier().get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': True,
#  'base_score': None,
#  'booster': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'gamma': None,
#  'gpu_id': None,
#  'importance_type': 'gain',
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
# Get best params based from CV function
def do_cv(classifier, cv_fun, params, x, y, **kwargs):
    clf = cv_fun(
        classifier,
        params,
        scoring='accuracy', # Optimize for the 'accuracy' score of the model.
        **kwargs,
    )
    clf.fit(x, y)
    return clf

# %% [markdown]
# ## Plot feature importances

# %%
def plot_feature_importances(clf, X, y):
    viz = FeatureImportances(clf, labels=X.columns)
    viz.fit(X, y)
    viz.show()

# %% [markdown]
# ## Train w/o pruning

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.metrics import classification_report

# %%
def print_all_metrics_and_plot(clf, X_train_dict, X_test_dict, grid_cv_params):
    for key in X_train_dict.keys():
        cv_clf = do_cv(
            clf,
            RandomizedSearchCV,
            grid_cv_params,
            X_train_dict[key],
            y_train_dict[key],
        )
        print(key.upper()+':\n')
        print('Best XGBoost accuracy (%s): %.2f' % (str(cv_clf.best_params_), cv_clf.score(X_test_dict[key], y_test_dict[key])))
        print(classification_report(y_test_dict[key], cv_clf.best_estimator_.predict(X_test_dict[key])))
        plot_feature_importances(cv_clf.best_estimator_, X_train_dict[key], y_train_dict[key])
        print('---------------------------------------------')

# %%
print_all_metrics_and_plot(
    xgb.XGBClassifier(random_state=0,eval_metric='logloss'),
    X_train_dict,
    X_test_dict,
    {},
)
# Out:
# WINNER:
#
# Best XGBoost accuracy ({}): 0.71
#               precision    recall  f1-score   support
#
#            0       0.73      0.85      0.78       854
#            1       0.66      0.46      0.54       512
#
#     accuracy                           0.71      1366
#    macro avg       0.69      0.66      0.66      1366
# weighted avg       0.70      0.71      0.69      1366
# ---------------------------------------------
# FGP:
#
# Best XGBoost accuracy ({}): 0.70
#               precision    recall  f1-score   support
#
#            0       0.73      0.83      0.77       615
#            1       0.65      0.51      0.57       388
#
#     accuracy                           0.70      1003
#    macro avg       0.69      0.67      0.67      1003
# weighted avg       0.70      0.70      0.69      1003
# ---------------------------------------------
# FG3:
#
# Best XGBoost accuracy ({}): 0.64
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68       342
#            1       0.60      0.58      0.59       279
#
#     accuracy                           0.64       621
#    macro avg       0.63      0.63      0.63       621
# weighted avg       0.64      0.64      0.64       621
# ---------------------------------------------
# FT:
#
# Best XGBoost accuracy ({}): 0.65
#               precision    recall  f1-score   support
#
#            0       0.69      0.60      0.64       327
#            1       0.62      0.71      0.67       304
#
#     accuracy                           0.65       631
#    macro avg       0.66      0.66      0.65       631
# weighted avg       0.66      0.65      0.65       631
# ---------------------------------------------
# AST:
#
# Best XGBoost accuracy ({}): 0.68
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75       591
#            1       0.62      0.52      0.56       391
#
#     accuracy                           0.68       982
#    macro avg       0.66      0.65      0.65       982
# weighted avg       0.67      0.68      0.67       982
# ---------------------------------------------
# REB:
#
# Best XGBoost accuracy ({}): 0.63
#               precision    recall  f1-score   support
#
#            0       0.67      0.73      0.70       489
#            1       0.57      0.50      0.53       351
#
#     accuracy                           0.63       840
#    macro avg       0.62      0.61      0.61       840
# weighted avg       0.63      0.63      0.63       840
# ---------------------------------------------

# %% [markdown]
# ## Try prune max depth

# %%
print_all_metrics_and_plot(
    xgb.XGBClassifier(random_state=0,eval_metric='logloss'),
    X_train_dict,
    X_test_dict,
    {
        'max_depth': [*range(3,500)],
    },
)
# Out:
# WINNER:
#
# Best XGBoost accuracy ({'max_depth': 183}): 0.74
#               precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81       854
#            1       0.71      0.52      0.60       512
#
#     accuracy                           0.74      1366
#    macro avg       0.73      0.70      0.70      1366
# weighted avg       0.74      0.74      0.73      1366
# ---------------------------------------------
# FGP:
#
# Best XGBoost accuracy ({'max_depth': 296}): 0.72
#               precision    recall  f1-score   support
#
#            0       0.74      0.86      0.79       615
#            1       0.69      0.52      0.59       388
#
#     accuracy                           0.72      1003
#    macro avg       0.72      0.69      0.69      1003
# weighted avg       0.72      0.72      0.72      1003
# ---------------------------------------------
# FG3:
#
# Best XGBoost accuracy ({'max_depth': 23}): 0.67
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.70       342
#            1       0.64      0.62      0.63       279
#
#     accuracy                           0.67       621
#    macro avg       0.67      0.67      0.67       621
# weighted avg       0.67      0.67      0.67       621
# ---------------------------------------------
# FT:
#
# Best XGBoost accuracy ({'max_depth': 492}): 0.65
#               precision    recall  f1-score   support
#
#            0       0.68      0.59      0.64       327
#            1       0.62      0.70      0.66       304
#
#     accuracy                           0.65       631
#    macro avg       0.65      0.65      0.65       631
# weighted avg       0.65      0.65      0.65       631
# ---------------------------------------------
# AST:
#
# Best XGBoost accuracy ({'max_depth': 29}): 0.71
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77       591
#            1       0.66      0.54      0.60       391
#
#     accuracy                           0.71       982
#    macro avg       0.69      0.68      0.68       982
# weighted avg       0.70      0.71      0.70       982
# ---------------------------------------------
# REB:
#
# Best XGBoost accuracy ({'max_depth': 377}): 0.66
#               precision    recall  f1-score   support
#
#            0       0.69      0.77      0.73       489
#            1       0.61      0.51      0.56       351
#
#     accuracy                           0.66       840
#    macro avg       0.65      0.64      0.64       840
# weighted avg       0.66      0.66      0.65       840
# ---------------------------------------------

# %% [markdown]
# ## Try prune reg_lambda

# %%
print_all_metrics_and_plot(
    xgb.XGBClassifier(random_state=0,eval_metric='logloss'),
    X_train_dict,
    X_test_dict,
    {
    'reg_lambda': [0.0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95,1],
    },
)
# Out:
# WINNER:
#
# Best XGBoost accuracy ({'reg_lambda': 0.7}): 0.70
#               precision    recall  f1-score   support
#
#            0       0.73      0.84      0.78       854
#            1       0.65      0.47      0.55       512
#
#     accuracy                           0.70      1366
#    macro avg       0.69      0.66      0.66      1366
# weighted avg       0.70      0.70      0.69      1366
# ---------------------------------------------
# FGP:
#
# Best XGBoost accuracy ({'reg_lambda': 0.05}): 0.68
#               precision    recall  f1-score   support
#
#            0       0.71      0.80      0.76       615
#            1       0.61      0.48      0.54       388
#
#     accuracy                           0.68      1003
#    macro avg       0.66      0.64      0.65      1003
# weighted avg       0.67      0.68      0.67      1003
# ---------------------------------------------
# FG3:
#
# Best XGBoost accuracy ({'reg_lambda': 0.6}): 0.65
#               precision    recall  f1-score   support
#
#            0       0.68      0.71      0.69       342
#            1       0.62      0.59      0.60       279
#
#     accuracy                           0.65       621
#    macro avg       0.65      0.65      0.65       621
# weighted avg       0.65      0.65      0.65       621
# ---------------------------------------------
# FT:
#
# Best XGBoost accuracy ({'reg_lambda': 0.1}): 0.65
#               precision    recall  f1-score   support
#
#            0       0.68      0.62      0.65       327
#            1       0.62      0.68      0.65       304
#
#     accuracy                           0.65       631
#    macro avg       0.65      0.65      0.65       631
# weighted avg       0.65      0.65      0.65       631
# ---------------------------------------------
# AST:
#
# Best XGBoost accuracy ({'reg_lambda': 0.95}): 0.67
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74       591
#            1       0.61      0.52      0.56       391
#
#     accuracy                           0.67       982
#    macro avg       0.66      0.65      0.65       982
# weighted avg       0.67      0.67      0.67       982
# ---------------------------------------------
# REB:
#
# Best XGBoost accuracy ({'reg_lambda': 0.7}): 0.65
#               precision    recall  f1-score   support
#
#            0       0.68      0.74      0.71       489
#            1       0.59      0.51      0.55       351
#
#     accuracy                           0.65       840
#    macro avg       0.64      0.63      0.63       840
# weighted avg       0.64      0.65      0.64       840
# ---------------------------------------------

# %% [markdown]
# ## Try prune gamma

# %%
print_all_metrics_and_plot(
    xgb.XGBClassifier(random_state=0,eval_metric='logloss'),
    X_train_dict,
    X_test_dict,
    {
    'gamma' : [*range(0,500)],

    },
)
# Out:
# WINNER:
#
# Best XGBoost accuracy ({'gamma': 43}): 0.63
#               precision    recall  f1-score   support
#
#            0       0.63      1.00      0.77       854
#            1       0.00      0.00      0.00       512
#
#     accuracy                           0.63      1366
#    macro avg       0.31      0.50      0.38      1366
# weighted avg       0.39      0.63      0.48      1366
# ---------------------------------------------
# FGP:
#
# Best XGBoost accuracy ({'gamma': 367}): 0.61
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       615
#            1       0.00      0.00      0.00       388
#
#     accuracy                           0.61      1003
#    macro avg       0.31      0.50      0.38      1003
# weighted avg       0.38      0.61      0.47      1003
# ---------------------------------------------
# FG3:
#
# Best XGBoost accuracy ({'gamma': 68}): 0.55
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71       342
#            1       0.00      0.00      0.00       279
#
#     accuracy                           0.55       621
#    macro avg       0.28      0.50      0.36       621
# weighted avg       0.30      0.55      0.39       621
# ---------------------------------------------
# FT:
#
# Best XGBoost accuracy ({'gamma': 130}): 0.48
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       327
#            1       0.48      1.00      0.65       304
#
#     accuracy                           0.48       631
#    macro avg       0.24      0.50      0.33       631
# weighted avg       0.23      0.48      0.31       631
# ---------------------------------------------
# AST:
#
# Best XGBoost accuracy ({'gamma': 18}): 0.60
#               precision    recall  f1-score   support
#
#            0       0.61      0.96      0.74       591
#            1       0.53      0.07      0.13       391
#
#     accuracy                           0.60       982
#    macro avg       0.57      0.52      0.44       982
# weighted avg       0.58      0.60      0.50       982
# ---------------------------------------------
# REB:
#
# Best XGBoost accuracy ({'gamma': 190}): 0.58
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       489
#            1       0.00      0.00      0.00       351
#
#     accuracy                           0.58       840
#    macro avg       0.29      0.50      0.37       840
# weighted avg       0.34      0.58      0.43       840
# ---------------------------------------------

# %% [markdown]
# ## Try prune scale_pos_weight

# %%
print_all_metrics_and_plot(
    xgb.XGBClassifier(random_state=0,eval_metric='logloss'),
    X_train_dict,
    X_test_dict,
    {
    'scale_pos_weight' : [*range(0,500)],

    },
)
# Out:
# WINNER:
#
# Best XGBoost accuracy ({'scale_pos_weight': 17}): 0.62
#               precision    recall  f1-score   support
#
#            0       0.83      0.50      0.62       854
#            1       0.50      0.82      0.62       512
#
#     accuracy                           0.62      1366
#    macro avg       0.66      0.66      0.62      1366
# weighted avg       0.70      0.62      0.62      1366
# ---------------------------------------------
# FGP:
#
# Best XGBoost accuracy ({'scale_pos_weight': 66}): 0.53
#               precision    recall  f1-score   support
#
#            0       0.77      0.34      0.47       615
#            1       0.44      0.84      0.58       388
#
#     accuracy                           0.53      1003
#    macro avg       0.61      0.59      0.53      1003
# weighted avg       0.64      0.53      0.51      1003
# ---------------------------------------------
# FG3:
#
# Best XGBoost accuracy ({'scale_pos_weight': 253}): 0.56
#               precision    recall  f1-score   support
#
#            0       0.78      0.29      0.42       342
#            1       0.51      0.90      0.65       279
#
#     accuracy                           0.56       621
#    macro avg       0.65      0.59      0.54       621
# weighted avg       0.66      0.56      0.52       621
# ---------------------------------------------
# FT:
#
# Best XGBoost accuracy ({'scale_pos_weight': 1}): 0.65
#               precision    recall  f1-score   support
#
#            0       0.69      0.60      0.64       327
#            1       0.62      0.71      0.67       304
#
#     accuracy                           0.65       631
#    macro avg       0.66      0.66      0.65       631
# weighted avg       0.66      0.65      0.65       631
# ---------------------------------------------
# AST:
#
# Best XGBoost accuracy ({'scale_pos_weight': 94}): 0.50
#               precision    recall  f1-score   support
#
#            0       0.71      0.30      0.42       591
#            1       0.43      0.81      0.57       391
#
#     accuracy                           0.50       982
#    macro avg       0.57      0.56      0.49       982
# weighted avg       0.60      0.50      0.48       982
# ---------------------------------------------
# REB:
#
# Best XGBoost accuracy ({'scale_pos_weight': 20}): 0.56
#               precision    recall  f1-score   support
#
#            0       0.73      0.38      0.50       489
#            1       0.48      0.81      0.60       351
#
#     accuracy                           0.56       840
#    macro avg       0.61      0.59      0.55       840
# weighted avg       0.63      0.56      0.54       840
# ---------------------------------------------

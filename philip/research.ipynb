# %%
## Make width of notebook 100%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from sklearn.preprocessing import MinMaxScaler, StandardScaler
sys.path.append('../')
from datasets import data as Local ## Local module to get dataframes

# %%
games_df, winners_df, cumulative_stats_df, games_details_df, teams_df, players_df, ranking_df = Local.get_all_dataset_dataframes('../datasets/')

# %% [markdown]
# # The Datasets

# %% [markdown]
# ## Issue w/ dataset
#
# The dataset is currently lacking data that can be used for prediction since most of the data is after the fact. Specifically, we are trying to predict winners of a game but the current data shows only the stats of the game after it has completed, so this data can't be used to predict winners.
#
# ### Solution:
#
# We've created new cumulative datasets by leveraging the current datasets and also using stats.nba.com's API.
#
# ~We need to scrape more data from stats.nba.com and/or create a new dataset from the existing datasets, to create data that can be used to build a model for predicting winners, i.e. stats of a team/player on the day of a game.~
#
# Todo:
# - Add columns for team stats to the rankings.csv dataset
# - Create a new dataset for player stats on the day of a game (before the game starts)

# %%
winners_df # Whether the home team won in a game in each row of `games_df`
# Out:
# 16157    1
# 16156    1
# 16155    1
# 16154    1
# 16153    1
#         ..
# 4        0
# 3        0
# 2        0
# 1        1
# 0        1
# Name: HOME_TEAM_WINS, Length: 23520, dtype: int64

# %%
games_df
# Out:
#       GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  \
# 16157    2003-10-05  10300001    1610612762       1610612742    2003
# 16156    2003-10-06  10300002    1610612763       1610612749    2003
# 16155    2003-10-07  10300009    1610612758       1610612746    2003
# 16154    2003-10-07  10300005    1610612757       1610612745    2003
# 16153    2003-10-07  10300007    1610612748       1610612755    2003
# ...             ...       ...           ...              ...     ...
# 4        2020-12-18  12000040    1610612761       1610612748    2020
# 3        2020-12-18  12000039    1610612754       1610612755    2020
# 2        2020-12-19  12000049    1610612763       1610612737    2020
# 1        2020-12-19  12000048    1610612764       1610612765    2020
# 0        2020-12-19  12000047    1610612753       1610612766    2020
#
#        PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  REB_home  \
# 16157      90.0        0.457        0.735         0.143      23.0      41.0
# 16156     105.0        0.494        0.618         0.267      25.0      48.0
# 16155     101.0        0.467        0.871         0.444      19.0      39.0
# 16154     104.0        0.527        0.657         0.429      22.0      33.0
# 16153      86.0        0.352        0.647         0.222      15.0      55.0
# ...         ...          ...          ...           ...       ...       ...
# 4         105.0        0.380        0.737         0.356      27.0      37.0
# 3         107.0        0.371        0.692         0.262      19.0      45.0
# 2         116.0        0.400        0.744         0.396      21.0      43.0
# 1          99.0        0.427        0.625         0.295      24.0      45.0
# 0         120.0        0.433        0.792         0.425      23.0      50.0
#
#        PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away
# 16157      85.0        0.447        0.500         0.250      20.0      38.0
# 16156      94.0        0.427        0.700         0.154      20.0      43.0
# 16155      82.0        0.368        0.609         0.364      13.0      50.0
# 16154      80.0        0.470        0.667         0.333      10.0      37.0
# 16153      79.0        0.329        0.897         0.143       7.0      44.0
# ...         ...          ...          ...           ...       ...       ...
# 4         117.0        0.534        0.741         0.514      30.0      51.0
# 3         113.0        0.533        0.629         0.355      23.0      48.0
# 2         117.0        0.422        0.837         0.297      24.0      47.0
# 1          96.0        0.402        0.647         0.326      18.0      51.0
# 0         117.0        0.444        0.864         0.439      21.0      52.0
#
# [23520 rows x 17 columns]

# %%
cumulative_stats_df
# Out:
#              DATE   GAME_ID     TEAM_ID  SEASON_TYPE  SEASON  AT_HOME  \
# 0      2003-10-05  10300001  1610612762            1    2003     True
# 1      2003-10-05  10300001  1610612742            1    2003    False
# 2      2003-10-06  10300002  1610612763            1    2003     True
# 3      2003-10-06  10300002  1610612749            1    2003    False
# 4      2003-10-07  10300009  1610612758            1    2003     True
# ...           ...       ...         ...          ...     ...      ...
# 47035  2020-12-19  12000049  1610612737            1    2020     True
# 47036  2020-12-19  12000048  1610612764            1    2020    False
# 47037  2020-12-19  12000048  1610612765            1    2020     True
# 47038  2020-12-19  12000047  1610612753            1    2020    False
# 47039  2020-12-19  12000047  1610612766            1    2020     True
#
#        PTS_total  AST_total  GAMES_PLAYED  REB_total  RPG_total  \
# 0           90.0       23.0             1       41.0  41.000000
# 1           85.0       20.0             1       38.0  38.000000
# 2          105.0       25.0             1       48.0  48.000000
# 3           94.0       20.0             1       43.0  43.000000
# 4          101.0       19.0             1       39.0  39.000000
# ...          ...        ...           ...        ...        ...
# 47035      451.0       96.0             4      215.0  53.750000
# 47036      299.0       68.0             3      134.0  44.666667
# 47037      376.0       78.0             4      176.0  44.000000
# 47038      458.0       98.0             4      204.0  51.000000
# 47039      449.0      110.0             4      187.0  46.750000
#
#        FG3_PCT_total  FG_PCT_total  APG_total  FT_PCT_total   PPG_total  \
# 0           0.143000       0.45700  23.000000       0.73500   90.000000
# 1           0.250000       0.44700  20.000000       0.50000   85.000000
# 2           0.267000       0.49400  25.000000       0.61800  105.000000
# 3           0.154000       0.42700  20.000000       0.70000   94.000000
# 4           0.444000       0.46700  19.000000       0.87100  101.000000
# ...              ...           ...        ...           ...         ...
# 47035       0.323500       0.40000  24.000000       0.80150  112.750000
# 47036       0.312667       0.41900  22.666667       0.67800   99.666667
# 47037       0.331250       0.41050  19.500000       0.69650   94.000000
# 47038       0.335250       0.44150  24.500000       0.76650  114.500000
# 47039       0.389000       0.44275  27.500000       0.77925  112.250000
#
#        sum_FG3_PCT_total  sum_FG_PCT_total  sum_FT_PCT_total
# 0                  0.143             0.457             0.735
# 1                  0.250             0.447             0.500
# 2                  0.267             0.494             0.618
# 3                  0.154             0.427             0.700
# 4                  0.444             0.467             0.871
# ...                  ...               ...               ...
# 47035              1.294             1.600             3.206
# 47036              0.938             1.257             2.034
# 47037              1.325             1.642             2.786
# 47038              1.341             1.766             3.066
# 47039              1.556             1.771             3.117
#
# [47040 rows x 19 columns]

# %%
games_details_df
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0       12000047  1610612766               CHA  Charlotte    1628998
# 1       12000047  1610612766               CHA  Charlotte    1629023
# 2       12000047  1610612766               CHA  Charlotte     203469
# 3       12000047  1610612766               CHA  Charlotte    1628984
# 4       12000047  1610612766               CHA  Charlotte    1626179
# ...          ...         ...               ...        ...        ...
# 585789  11200005  1610612743               DEN     Denver     202706
# 585790  11200005  1610612743               DEN     Denver     202702
# 585791  11200005  1610612743               DEN     Denver     201585
# 585792  11200005  1610612743               DEN     Denver     202389
# 585793  11200005  1610612743               DEN     Denver     201951
#
#             PLAYER_NAME START_POSITION COMMENT    MIN  FGM  ...  OREB  DREB  \
# 0           Cody Martin              F     NaN  17:06  0.0  ...   0.0   2.0
# 1       P.J. Washington              F     NaN  24:58  4.0  ...   1.0   6.0
# 2           Cody Zeller              C     NaN  22:45  5.0  ...   2.0   2.0
# 3       Devonte' Graham              G     NaN  31:30  8.0  ...   1.0   3.0
# 4          Terry Rozier              G     NaN  26:48  8.0  ...   1.0   4.0
# ...                 ...            ...     ...    ...  ...  ...   ...   ...
# 585789  Jordan Hamilton            NaN     NaN     19  4.0  ...   0.0   2.0
# 585790   Kenneth Faried            NaN     NaN     23  7.0  ...   1.0   0.0
# 585791     Kosta Koufos            NaN     NaN     15  3.0  ...   3.0   5.0
# 585792   Timofey Mozgov            NaN     NaN     19  1.0  ...   1.0   2.0
# 585793        Ty Lawson            NaN     NaN     27  3.0  ...   0.0   2.0
#
#         REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0       2.0  1.0  0.0  1.0  1.0  2.0   0.0       -31.0
# 1       7.0  2.0  2.0  1.0  5.0  3.0   9.0        -2.0
# 2       4.0  0.0  0.0  1.0  0.0  2.0  13.0       -23.0
# 3       4.0  3.0  2.0  0.0  4.0  0.0  25.0        -7.0
# 4       5.0  6.0  1.0  0.0  0.0  2.0  24.0        22.0
# ...     ...  ...  ...  ...  ...  ...   ...         ...
# 585789  2.0  0.0  2.0  0.0  1.0  3.0  17.0         NaN
# 585790  1.0  1.0  1.0  0.0  3.0  3.0  18.0         NaN
# 585791  8.0  0.0  1.0  0.0  0.0  3.0   6.0         NaN
# 585792  3.0  1.0  0.0  0.0  4.0  2.0   2.0         NaN
# 585793  2.0  6.0  2.0  0.0  6.0  1.0   8.0         NaN
#
# [585794 rows x 28 columns]

# %%
ranking_df
# TODO: add columns for Team Stats (PPG, FGP, etc) from stats.nba.com
# RETURNTOPLAY is the period of games after restart due to covid lockdowns in the 19-20 season. https://www.nba.com/stats/returntoplay2020/
# Out:
#            TEAM_ID  SEASON_ID STANDINGSDATE CONFERENCE          TEAM   G   W  \
# 159591  1610612752      22002    2003-10-01       East      New York  82  37
# 159583  1610612765      22002    2003-10-01       East       Detroit  82  50
# 159584  1610612751      22002    2003-10-01       East    New Jersey  82  49
# 159585  1610612754      22002    2003-10-01       East       Indiana  82  48
# 159586  1610612755      22002    2003-10-01       East  Philadelphia  82  48
# ...            ...        ...           ...        ...           ...  ..  ..
# 4429    1610612761      12020    2020-12-21       East       Toronto   3   2
# 4428    1610612752      12020    2020-12-21       East      New York   4   3
# 4427    1610612741      12020    2020-12-21       East       Chicago   4   3
# 4425    1610612751      12020    2020-12-21       East      Brooklyn   2   2
# 0       1610612747      12020    2020-12-21       West   L.A. Lakers   4   4
#
#          L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 159591  45  0.451       24-17       13-28           NaN
# 159583  32  0.610       30-11       20-21           NaN
# 159584  33  0.598        33-8       16-25           NaN
# 159585  34  0.585        32-9       16-25           NaN
# 159586  34  0.585       25-16       23-18           NaN
# ...     ..    ...         ...         ...           ...
# 4429     1  0.667         0-1         2-0           NaN
# 4428     1  0.750         2-0         1-1           NaN
# 4427     1  0.750         1-1         2-0           NaN
# 4425     0  1.000         1-0         1-0           NaN
# 0        0  1.000         2-0         2-0           NaN
#
# [188383 rows x 12 columns]

# %%
teams_df
# Out:
#        TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME           CITY  \
# 0   1610612737      1949      2019          ATL          Hawks        Atlanta
# 1   1610612738      1946      2019          BOS        Celtics         Boston
# 2   1610612740      2002      2019          NOP       Pelicans    New Orleans
# 3   1610612741      1966      2019          CHI          Bulls        Chicago
# 4   1610612742      1980      2019          DAL      Mavericks         Dallas
# 5   1610612743      1976      2019          DEN        Nuggets         Denver
# 6   1610612745      1967      2019          HOU        Rockets        Houston
# 7   1610612746      1970      2019          LAC       Clippers    Los Angeles
# 8   1610612747      1948      2019          LAL         Lakers    Los Angeles
# 9   1610612748      1988      2019          MIA           Heat          Miami
# 10  1610612749      1968      2019          MIL          Bucks      Milwaukee
# 11  1610612750      1989      2019          MIN   Timberwolves      Minnesota
# 12  1610612751      1976      2019          BKN           Nets       Brooklyn
# 13  1610612752      1946      2019          NYK         Knicks       New York
# 14  1610612753      1989      2019          ORL          Magic        Orlando
# 15  1610612754      1976      2019          IND         Pacers        Indiana
# 16  1610612755      1949      2019          PHI          76ers   Philadelphia
# 17  1610612756      1968      2019          PHX           Suns        Phoenix
# 18  1610612757      1970      2019          POR  Trail Blazers       Portland
# 19  1610612758      1948      2019          SAC          Kings     Sacramento
# 20  1610612759      1976      2019          SAS          Spurs    San Antonio
# 21  1610612760      1967      2019          OKC        Thunder  Oklahoma City
# 22  1610612761      1995      2019          TOR        Raptors        Toronto
# 23  1610612762      1974      2019          UTA           Jazz           Utah
# 24  1610612763      1995      2019          MEM      Grizzlies        Memphis
# 25  1610612764      1961      2019          WAS        Wizards     Washington
# 26  1610612765      1948      2019          DET        Pistons        Detroit
# 27  1610612766      1988      2019          CHA        Hornets      Charlotte
# 28  1610612739      1970      2019          CLE      Cavaliers      Cleveland
# 29  1610612744      1946      2019          GSW       Warriors   Golden State
#
#     ARENACAPACITY                                OWNER   GENERALMANAGER  \
# 0         18729.0                         Tony Ressler   Travis Schlenk
# 1         18624.0                        Wyc Grousbeck      Danny Ainge
# 2             NaN                           Tom Benson   Trajan Langdon
# 3         21711.0                      Jerry Reinsdorf       Gar Forman
# 4         19200.0                           Mark Cuban    Donnie Nelson
# 5         19099.0                         Stan Kroenke     Tim Connelly
# 6         18104.0                      Tilman Fertitta      Daryl Morey
# 7         19060.0                        Steve Ballmer   Michael Winger
# 8         19060.0              Jerry Buss Family Trust      Rob Pelinka
# 9         19600.0                         Micky Arison        Pat Riley
# 10        17500.0            Wesley Edens & Marc Lasry        Jon Horst
# 11        19356.0                          Glen Taylor     Scott Layden
# 12            NaN                             Joe Tsai       Sean Marks
# 13        19763.0            Cablevision (James Dolan)      Steve Mills
# 14            0.0                           Rick DeVos     John Hammond
# 15        18345.0                           Herb Simon  Kevin Pritchard
# 16            NaN                        Joshua Harris      Elton Brand
# 17            NaN                        Robert Sarver      James Jones
# 18        19980.0                           Paul Allen      Neil Olshey
# 19        17500.0                       Vivek Ranadive      Vlade Divac
# 20        18694.0                           Peter Holt     Brian Wright
# 21        19163.0                         Clay Bennett       Sam Presti
# 22        19800.0  Maple Leaf Sports and Entertainment      Masai Ujiri
# 23        20148.0                          Greg Miller   Dennis Lindsey
# 24        18119.0                          Robert Pera     Zach Kleiman
# 25        20647.0                          Ted Leonsis   Tommy Sheppard
# 26        21000.0                            Tom Gores     Ed Stefanski
# 27        19026.0                       Michael Jordan    Mitch Kupchak
# 28        20562.0                          Dan Gilbert      Koby Altman
# 29        19596.0                            Joe Lacob        Bob Myers
#
#            HEADCOACH
# 0       Lloyd Pierce
# 1       Brad Stevens
# 2       Alvin Gentry
# 3         Jim Boylen
# 4      Rick Carlisle
# 5     Michael Malone
# 6      Mike D'Antoni
# 7         Doc Rivers
# 8        Frank Vogel
# 9     Erik Spoelstra
# 10  Mike Budenholzer
# 11     Ryan Saunders
# 12    Kenny Atkinson
# 13     David Fizdale
# 14    Steve Clifford
# 15     Nate McMillan
# 16       Brett Brown
# 17    Monty Williams
# 18      Terry Stotts
# 19       Luke Walton
# 20    Gregg Popovich
# 21     Billy Donovan
# 22        Nick Nurse
# 23       Quin Snyder
# 24    Taylor Jenkins
# 25      Scott Brooks
# 26       Dwane Casey
# 27     James Borrego
# 28      John Beilein
# 29        Steve Kerr

# %%
players_df
# Out:
#            PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0        Royce O'Neale  1610612762    1626220    2019
# 1     Bojan Bogdanovic  1610612762     202711    2019
# 2          Rudy Gobert  1610612762     203497    2019
# 3     Donovan Mitchell  1610612762    1628378    2019
# 4          Mike Conley  1610612762     201144    2019
# ...                ...         ...        ...     ...
# 7223       Lanny Smith  1610612758     201831    2009
# 7224     Warren Carter  1610612752     201999    2009
# 7225      Bennet Davis  1610612751     201834    2009
# 7226    Brian Hamilton  1610612751     201646    2009
# 7227   Wesley Matthews  1610612762     500032    2009
#
# [7228 rows x 4 columns]

# %% [markdown]
# # Exploring the Data

# %%
# Create df with only data
games_data_df = games_df.copy()
for k in ['GAME_DATE_EST','GAME_ID','HOME_TEAM_ID','VISITOR_TEAM_ID','SEASON','TEAM_ID_home','TEAM_ID_away']:
    del games_data_df[k]
games_data_df['HOME_TEAM_WINS'] = winners_df.copy()
# Create a standard scaled df
standardized_games_data_df = pd.DataFrame(StandardScaler().fit_transform(games_data_df), columns=games_data_df.columns)

# %% [markdown]
# ## Covariance Matrices

# %%
standardized_games_data_df.cov().style.background_gradient(cmap='rainbow',axis=None)
# Out:
# <style  type="text/css" >
# #T_bb275572_90f8_11eb_9a55_984827464b81row0_col0,#T_bb275572_90f8_11eb_9a55_984827464b81row1_col1,#T_bb275572_90f8_11eb_9a55_984827464b81row2_col2,#T_bb275572_90f8_11eb_9a55_984827464b81row3_col3,#T_bb275572_90f8_11eb_9a55_984827464b81row4_col4,#T_bb275572_90f8_11eb_9a55_984827464b81row5_col5,#T_bb275572_90f8_11eb_9a55_984827464b81row6_col6,#T_bb275572_90f8_11eb_9a55_984827464b81row7_col7,#T_bb275572_90f8_11eb_9a55_984827464b81row8_col8,#T_bb275572_90f8_11eb_9a55_984827464b81row9_col9,#T_bb275572_90f8_11eb_9a55_984827464b81row10_col10,#T_bb275572_90f8_11eb_9a55_984827464b81row11_col11,#T_bb275572_90f8_11eb_9a55_984827464b81row12_col12{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_bb275572_90f8_11eb_9a55_984827464b81row0_col1,#T_bb275572_90f8_11eb_9a55_984827464b81row1_col0{
#             background-color:  #ffa759;
#             color:  #000000;
#         }#T_bb275572_90f8_11eb_9a55_984827464b81row0_col2,#T_bb275572_90f8_11eb_9a55_984827464b81row2_col0{
#             background-color:  #62fbc4;
#             color:  #000000;
#         }#T_bb275572_90f8_11eb_9a55_984827464b81row0_col3,#T_bb275572_90f8_11eb_9a55_984827464b81row3_col0{
#             background-color:  #b6f193;
#             color:  #000000;
#         }#T_bb275572_90f8_11eb_9a55_984827464b81row0_col4,#T_bb275572_90f8_11eb_9a55_984827464b81row4_col0{
#             background-color:  #f2c26b;
#             color:  #000000;
#         }#T_bb275572_90f8_11eb_9a55_984827464b81row0_col5,#T_bb275572_90f8_11eb_9a55_984827464b81row5_col0{
#             background-color:  #5af8c8;
#             color:  #000000;
#         }#T_bb275572_90f8_11eb_9a55_984827464b81row0_col6,#T_bb275572_90f8_11eb_9a55_984827464b81row6_col0{
#             background-color:  #c8e688;
#             color:  #000000;
#         }#T_bb275572_90f8_11eb_9a55_984827464b81row0_col7,#T_bb275572_90f8_11eb_9a55_984827464b81row4_col10,#T_bb275572_90f8_11eb_9a55_984827464b81row7_col0,#T_bb275572_90f8_11eb_9a55_984827464b81row10_col4{
#             background-color:  #50f4cc;
#             color:  #000000;
#         }#T_bb275572_90f8_11eb_9a55_984827464b81row0_col8,#T_bb275572_90f8_11eb_9a55_984827464b81row8_col0{
#             background-color:  #3ae8d6;
#             color:  #000000;
#         }#T_bb275572_90f8_11eb_9a55_984827464b81row3_col4,#T_bb275572_90f8_11eb_9a55_984827464b81row4_col3{
#             background-color:  #9cfba4;
#             color:  #000000;
#         }#T_bb275572_90f8_11eb_9a55_984827464b81row3_col5,#T_bb275572_90f8_1

# %% [markdown]
# ## Scatter Matrices

# %%
sm=pd.plotting.scatter_matrix(
    standardized_games_data_df,
    alpha=0.25,
    figsize=(18,18),
    diagonal='hist',
    range_padding=0.3, # More padding to fit labels
    c=['c','m']*(23421//2) + ['c'], # Color differentiate points from different data
)
# Rotate & reposition labels
# (referenced https://stackoverflow.com/questions/32560932/how-to-customize-a-scatter-matrix-to-see-all-titles)
for s in sm.reshape(-1):
    s.xaxis.label.set_rotation(45)
    s.yaxis.label.set_rotation(0)
    s.get_yaxis().set_label_coords(-1.1,0.5)
plt.suptitle('Scatter Matrix (Standard Scaled Data)')
plt.show()

# %% [markdown]
# ## Quantifying home team advantage
# Teams playing at home have the advantage over the visiting teams; The home team win rate overall is 59.1%.
#
# In addition, home teams data shows greater means than the visiting teams in the following:
# - 2.9 more points
# - 1.1% more FGP
# - 1.3 more rebounds
# - 1.4 more assists

# %%
winners_df.describe()
# Out:
# count    23520.000000
# mean         0.591029
# std          0.491654
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: HOME_TEAM_WINS, dtype: float64

# %%
def plot_diff(d1,d2,title,bins=30,alpha=0.6):
    d1.plot.hist(bins=bins, title=title, alpha=alpha)
    d2.plot.hist(bins=bins, alpha=alpha)
    plt.legend()
    plt.show()
    print('Difference:')
    print((d1-d2).describe())

# %%
plot_diff(games_df['PTS_home'], games_df['PTS_away'], 'Points by home vs. Points by away')
# Out:
# Difference:
# count    23421.000000
# mean         2.946843
# std         13.289384
# min        -58.000000
# 25%         -6.000000
# 50%          4.000000
# 75%         11.000000
# max         61.000000
# dtype: float64

# %%
plot_diff(games_df['FG_PCT_home'], games_df['FG_PCT_away'], 'FGP of home vs. FGP of away')
# Out:
# Difference:
# count    23421.000000
# mean         0.011578
# std          0.077756
# min         -0.307000
# 25%         -0.040000
# 50%          0.011000
# 75%          0.065000
# max          0.319000
# dtype: float64

# %%
plot_diff(games_df['FG3_PCT_home'], games_df['FG3_PCT_away'], '3PT-FGP of home vs. 3PT-FGP of away')
# Out:
# Difference:
# count    23421.000000
# mean         0.006705
# std          0.160215
# min         -0.800000
# 25%         -0.098000
# 50%          0.007000
# 75%          0.112000
# max          0.700000
# dtype: float64

# %%
plot_diff(games_df['REB_home'], games_df['REB_away'], 'Rebounds by home vs. Rebounds by away')
# Out:
# Difference:
# count    23421.000000
# mean         1.314504
# std          8.945655
# min        -39.000000
# 25%         -5.000000
# 50%          1.000000
# 75%          7.000000
# max         38.000000
# dtype: float64

# %%
plot_diff(games_df['AST_home'], games_df['AST_away'], 'Assists by home vs. Assists by away',bins=20)
# Out:
# Difference:
# count    23421.000000
# mean         1.399385
# std          6.748116
# min        -24.000000
# 25%         -3.000000
# 50%          1.000000
# 75%          6.000000
# max         26.000000
# dtype: float64
